# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
# %matplotlib inline

# %%
#carga de imágenes y paso a RGB

tito_1 = cv.imread('./material_TPs/TP1/CoordCrom_1.png')
tito_1_RGB = cv.cvtColor(tito_1, cv.COLOR_BGR2RGB)

tito_2 = cv.imread('./material_TPs/TP1/CoordCrom_2.png')
tito_2_RGB = cv.cvtColor(tito_2, cv.COLOR_BGR2RGB)

tito_3 = cv.imread('./material_TPs/TP1/CoordCrom_3.png')
tito_3_RGB = cv.cvtColor(tito_3, cv.COLOR_BGR2RGB)

# %%
plt.figure(1)
plt.imshow(tito_1_RGB)
plt.show()
print(tito_1_RGB.shape)
# Out:
# (996, 908, 3)

# %%
plt.figure(1)
plt.imshow(tito_2_RGB)
plt.show()
print(tito_2_RGB.shape)
# Out:
# (996, 908, 3)

# %%
plt.figure(1)
plt.imshow(tito_3_RGB)
plt.show()
print(tito_3_RGB.shape)
# Out:
# (996, 908, 3)

# %% [markdown]
# **TITO 1**

# %%
#pasaje a coordenadas cromáticas

suma = tito_1_RGB.sum(axis = 2)

suma[suma==0]=0.1
        
tito1R = tito_1_RGB[:,:,0] / suma
tito1G = tito_1_RGB[:,:,1] / suma
tito1B = tito_1_RGB[:,:,2] / suma

# %%
tito_1_RGB2 = cv.merge((np.uint8(tito1R*255), np.uint8(tito1G*255), np.uint8(tito1B*255)))

# %%
plt.imshow(tito_1_RGB2)
plt.show()
tito_1_RGB2.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# **TITO 2**

# %%
#pasaje a coordenadas cromáticas

suma = tito_2_RGB.sum(axis = 2)

suma[suma==0]=0.1

tito2R = tito_2_RGB[:,:,0] / suma
tito2G = tito_2_RGB[:,:,1] / suma
tito2B = tito_2_RGB[:,:,2] / suma

# %%
tito_2_RGB2 = cv.merge((np.uint8(tito2R*255), np.uint8(tito2G*255), np.uint8(tito2B*255)))

# %%
plt.imshow(tito_2_RGB2)
plt.show()
tito_2_RGB2.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# **TITO 3**

# %%
#pasaje a coordenadas cromáticas

suma = tito_3_RGB.sum(axis = 2)

suma[suma==0]=0.1

tito3R = tito_3_RGB[:,:,0] / suma
tito3G = tito_3_RGB[:,:,1] / suma
tito3B = tito_3_RGB[:,:,2] / suma

# %%
tito_3_RGB2 = cv.merge((np.uint8(tito3R*255), np.uint8(tito3G*255), np.uint8(tito3B*255)))

# %%
plt.imshow(tito_3_RGB2)
plt.show()
tito_3_RGB2.dtype
# Out:
# dtype('uint8')
