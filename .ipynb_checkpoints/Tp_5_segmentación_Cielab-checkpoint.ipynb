# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

# %%
# %matplotlib inline

# %% [markdown]
# ## K -means con HSV

# %%
img = cv.imread('./material_TPs/TP5/roca_lunar_2.jpg')
imgRGB = img[:,:,::-1]
plt.imshow(imgRGB)
plt.show()
imgRGB.shape
# Out:
# (312, 400, 3)

# %%
lab = cv.cvtColor(img,cv.COLOR_BGR2HSV)
lab.shape
# Out:
# (312, 400, 3)

# %%
plt.figure()
plt.imshow(lab)
plt.show()

# %% [markdown]
# ### Espacios de características

# %% [markdown]
# #### Espacio características color

# %%
features_color = lab.reshape((-1,3))
features_color = np.float32(features_color)
features_color_norm = features_color/np.max(features_color, axis = 0)

print(features_color_norm.shape)
print(features_color_norm.dtype)
# Out:
# (124800, 3)
# float32
# 0.0
# 1.0

# %% [markdown]
# ##### Espacio características color + posición

# %%
# obtener posiciones
pos = []

for j in range(0, 312):
    for i in range(0, 400):
        pos.append((j,i))

pos= np.asarray(pos)

#features finales
features_pos = np.concatenate((features_color, pos), axis=1)
features_pos_norm = features_pos/np.max(features_pos, axis = 0)
features_pos_norm = np.float32(features_pos_norm)

print(features_pos_norm.shape)
print(features_pos_norm.dtype)
print(np.min(features_pos_norm))
print(np.max(features_pos_norm))
# Out:
# (124800, 5)
# float32
# 0.0
# 1.0

# %% [markdown]
# ### gráficas de distribuciones

# %% [markdown]
# #### Espacio de características de color

# %%
fig = plt.figure(figsize=(10,10))
axis = fig.add_subplot(1, 1, 1, projection="3d")

pixel_colors = imgRGB.reshape((np.shape(imgRGB)[0]*np.shape(imgRGB)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()


axis.scatter(features_color_norm[:,0], features_color_norm[:,1], features_color_norm[:,2], facecolors=pixel_colors, marker=".")
axis.set_xlabel("Canal 1")
axis.set_ylabel("Canal 2")
axis.set_zlabel("Canal 3")
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.scatter(features_color_norm[:,0], features_color_norm[:,1], c=pixel_colors, edgecolor='none', alpha=0.7, s=40)
plt.title('2D');

# %% [markdown]
# #### Espacio de características color + pos

# %%
fig = plt.figure(figsize=(10,10))
axis = fig.add_subplot(1, 1, 1, projection="3d")

pixel_colors = imgRGB.reshape((np.shape(imgRGB)[0]*np.shape(imgRGB)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()


axis.scatter(features_pos[:,0], features_pos[:,4], features_pos[:,3], facecolors=pixel_colors, marker=".")
axis.set_xlabel("Canal 1")
axis.set_ylabel("Canal 2")
axis.set_zlabel("Canal 3")
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.scatter(features_pos[:,0],features_pos[:,4], c=pixel_colors, edgecolor='none', alpha=0.7, s=40)
plt.title('2D');

# %% [markdown]
# Es difícil identificar si hay un cluster específico para la roca porque el fondo y los otros objetos están dentro de los mismo tonos y no tienen una distribución reconocible.

# %% [markdown]
# ### Posterización

# %% [markdown]
# #### Espacio de características color

# %%
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 20, 1.0)
k = 4
compact, label, color_clusters = cv.kmeans(features_color_norm, k, None, criteria, 10, cv.KMEANS_RANDOM_CENTERS)

# %%
color_clusters = np.uint8(color_clusters * np.max(features_color, axis = 0))
print(f'Centroides: \n {color_clusters} \n') 
compact = np.uint8(compact)
print('Compactación: \n {} \n'.format(compact))
label[:4]
# Out:
# Centroides:
#  [[ 29  23 111]
#  [ 18 241   9]
#  [140  13  96]
#  [ 19  49  47]]
#
# Compactación:
#  199
# array([[3],
#        [3],
#        [3],
#        [3]], dtype=int32)

# %%
img_out = color_clusters[label.flatten()]
img_out = img_out.reshape((lab.shape))

img_rgb = cv.cvtColor(img_out,cv.COLOR_HSV2RGB)
plt.figure(figsize = (10,10))
plt.imshow(img_rgb)
plt.show()

np.max(img_out[:,0])
# Out:
# 140

# %%
mask_list = list()
for cluster in color_clusters:
    mask = np.zeros(img_out.shape[:2],'uint8')
    mask[np.where((img_out == cluster).all(axis=2))] = 255
    mask_list.append(mask)

# %%
for i, mask in enumerate(mask_list):
    img_segmented = cv.bitwise_and(lab, lab, mask = mask)
    plt.imshow(mask, cmap=plt.cm.gray)

# %% [markdown]
# #### Espacio de características color + pos

# %%
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 10, 1.0)
k =10
compact, label, color_clusters = cv.kmeans(features_pos_norm, k, None, criteria, 10, cv.KMEANS_RANDOM_CENTERS)

# %%
color_clusters = np.uint8(color_clusters * np.max(features_pos, axis = 0))
print(f'Centroides: \n {color_clusters} \n') 
compact = np.uint8(compact)
print('Compactación: \n {} \n'.format(compact))
label[:4]
# Out:
# Centroides:
#  [[162  20  48 205  93]
#  [ 24  36  48   0  54]
#  [ 22  47  74 131 250]
#  [ 84   5 140  41  77]
#  [ 19 119  26 137 236]
#  [ 15  20 121  51 142]
#  [160  28  33 249   6]
#  [ 18  39  53 241  83]
#  [ 15 159  18 134 107]
#  [ 22  33  87 100  59]]
#
# Compactación:
#  36
# array([[9],
#        [9],
#        [9],
#        [9]], dtype=int32)

# %%
img_out_2 = color_clusters[label.flatten()]
img_out_2 = img_out_2[:,:3].reshape((lab.shape))

img_rgb = cv.cvtColor(img_out_2,cv.COLOR_HSV2RGB)
plt.figure(figsize = (10,10))
plt.imshow(img_rgb)
plt.show()

img_out_2.shape
# Out:
# (312, 400, 3)

# %%
mask_list = list()
for cluster in color_clusters:
    mask = np.zeros(img_out_2.shape[:2],'uint8')
    mask[np.where((img_out_2 == cluster).all(axis=2))] = 255
    mask_list.append(mask)
# Out:
# C:\Users\apguz\AppData\Local\Temp\ipykernel_31272\127938479.py:4: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   mask[np.where((img_out_2 == cluster).all(axis=2))] = 255
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       2 for cluster in color_clusters:
#       3     mask = np.zeros(img_out_2.shape[:2],'uint8')
# ----> 4     mask[np.where((img_out_2 == cluster).all(axis=2))] = 255
#       5     mask_list.append(mask)
#
# AttributeError: 'bool' object has no attribute 'all'

# %%
for i, mask in enumerate(mask_list):
    img_segmented = cv.bitwise_and(lab, lab, mask = mask)
    plt.imshow(mask, cmap=plt.cm.gray)

# %% [markdown]
# ### Prueba con Mean Shift

# %%
sp = 20
sr = 40

img_out_3=cv.pyrMeanShiftFiltering(imgRGB, sp, sr)

plt.figure(figsize=(10,10))
plt.imshow(img_out_3)

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Pareciera que para esta imagen resultaría mejor usar algún otro espacio de características que no sea color. Podría usarse lbp dada la textura de la roca o probar algún otro espacio como HSV para ver si la distribución es paramétrica que ayude a la clusterización.
