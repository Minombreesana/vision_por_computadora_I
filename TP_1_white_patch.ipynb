# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
# %matplotlib inline

# %%
#carga de imágenes y paso a RGB

tito_1 = cv.imread('./material_TPs/TP1/WP_B.png')
tito_1_RGB = cv.cvtColor(tito_1, cv.COLOR_BGR2RGB)

tito_2 = cv.imread('./material_TPs/TP1/WP_O.png')
tito_2_RGB = cv.cvtColor(tito_2, cv.COLOR_BGR2RGB)

tito_3 = cv.imread('./material_TPs/TP1/WP_R.png')
tito_3_RGB = cv.cvtColor(tito_3, cv.COLOR_BGR2RGB)

# %%
plt.figure(1)
plt.imshow(tito_1_RGB)
plt.show()
print(tito_1_RGB.shape)
# Out:
# (565, 565, 3)

# %%
plt.figure(1)
plt.imshow(tito_2_RGB)
plt.show()
print(tito_2_RGB.shape)
# Out:
# (607, 607, 3)

# %%
plt.figure(1)
plt.imshow(tito_3_RGB)
plt.show()
print(tito_3_RGB.shape)
# Out:
# (565, 565, 3)

# %% [markdown]
# **TITO AZUL**

# %%
# Valores máximos para cada canal

r_max = np.max(tito_1_RGB[:,:,0])
g_max = np.max(tito_1_RGB[:,:,1])
b_max = np.max(tito_1_RGB[:,:,2])

print('R_max:', r_max)
print('G_max:', g_max)
print('B_max:', b_max)
# Out:
# R_max: 31
# G_max: 118
# B_max: 166

# %%
# Normalización
 
tito_r = tito_1_RGB[:,:,0]/r_max
tito_g = tito_1_RGB[:,:,1]/g_max
tito_b = tito_1_RGB[:,:,2]/b_max

# %%
tito_1_RGB2 = cv.merge((np.uint8(tito_r*255), np.uint8(tito_g*255), np.uint8(tito_b*255)))

# %%
plt.imshow(tito_1_RGB2)
plt.show()
tito_1_RGB2.dtype
# Out:
# dtype('uint8')

# %%
# Prueba con percentiles

per = 98

r_per = np.percentile(tito_1_RGB[:,:,0], per)
g_per = np.percentile(tito_1_RGB[:,:,1], per)
b_per = np.percentile(tito_1_RGB[:,:,2], per)

print('R_per:', r_per)
print('G_per:', g_per)
print('B_per:', b_per)
# Out:
# R_per: 5.0
# G_per: 96.0
# B_per: 150.0

# %%
# Normalización
 
tito_r_per = tito_1_RGB[:,:,0]/r_per
tito_g_per = tito_1_RGB[:,:,1]/g_per
tito_b_per = tito_1_RGB[:,:,2]/b_per

# %%
tito_1_RGB_per = cv.merge((np.uint8(tito_r_per*255), np.uint8(tito_g_per*255), np.uint8(tito_b_per*255)))

# %%
plt.imshow(tito_1_RGB_per)
plt.show()
tito_1_RGB_per.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# **TITO NARANJA**

# %%
# Valores máximos para cada canal

r2_max = np.max(tito_2_RGB[:,:,0])
g2_max = np.max(tito_2_RGB[:,:,1])
b2_max = np.max(tito_2_RGB[:,:,2])

print('R_max:', r2_max)
print('G_max:', g2_max)
print('B_max:', b2_max)
# Out:
# R_max: 199
# G_max: 112
# B_max: 49

# %%
# Normalización
 
tito_r2 = tito_2_RGB[:,:,0]/r2_max
tito_g2 = tito_2_RGB[:,:,1]/g2_max
tito_b2 = tito_2_RGB[:,:,2]/b2_max

# %%
tito_2_RGB2 = cv.merge((np.uint8(tito_r2*255), np.uint8(tito_g2*255), np.uint8(tito_b2*255)))

# %%
plt.imshow(tito_2_RGB2)
plt.show()
tito_2_RGB2.dtype
# Out:
# dtype('uint8')

# %%
# Prueba con percentiles

per = 99

r_per = np.percentile(tito_2_RGB[:,:,0], per)
g_per = np.percentile(tito_2_RGB[:,:,1], per)
b_per = np.percentile(tito_2_RGB[:,:,2], per)

print('R_per:', r_per)
print('G_per:', g_per)
print('B_per:', b_per)
# Out:
# R_per: 187.0
# G_per: 91.0
# B_per: 23.0

# %%
# Normalización
 
tito_r_per = tito_2_RGB[:,:,0]/r_per
tito_g_per = tito_2_RGB[:,:,1]/g_per
tito_b_per = tito_2_RGB[:,:,2]/b_per

# %%
tito_2_RGB_per = cv.merge((np.uint8(tito_r_per*255), np.uint8(tito_g_per*255), np.uint8(tito_b_per*255)))

# %%
plt.imshow(tito_2_RGB_per)
plt.show()
tito_2_RGB_per.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# **TITO VIOLETA**

# %%
# Valores máximos para cada canal

r3_max = np.max(tito_3_RGB[:,:,0])
g3_max = np.max(tito_3_RGB[:,:,1])
b3_max = np.max(tito_3_RGB[:,:,2])

print('R_max:', r3_max)
print('G_max:', g3_max)
print('B_max:', b3_max)
# Out:
# R_max: 208
# G_max: 47
# B_max: 173

# %%
# Normalización
 
tito_r3 = tito_3_RGB[:,:,0]/r3_max
tito_g3 = tito_3_RGB[:,:,1]/g3_max
tito_b3 = tito_3_RGB[:,:,2]/b3_max

# %%
tito_3_RGB2 = cv.merge((np.uint8(tito_r3*255), np.uint8(tito_g3*255), np.uint8(tito_b3*255)))

# %%
plt.imshow(tito_3_RGB2)
plt.show()
tito_3_RGB2.dtype
# Out:
# dtype('uint8')

# %%
# Prueba con percentiles

per = 98

r_per = np.percentile(tito_3_RGB[:,:,0], per)
g_per = np.percentile(tito_3_RGB[:,:,1], per)
b_per = np.percentile(tito_3_RGB[:,:,2], per)

print('R_per:', r_per)
print('G_per:', g_per)
print('B_per:', b_per)
# Out:
# R_per: 191.0
# G_per: 20.0
# B_per: 152.0

# %%
# Normalización
 
tito_r_per = tito_3_RGB[:,:,0]/r_per
tito_g_per = tito_3_RGB[:,:,1]/g_per
tito_b_per = tito_3_RGB[:,:,2]/b_per

# %%
tito_3_RGB_per = cv.merge((np.uint8(tito_r_per*255), np.uint8(tito_g_per*255), np.uint8(tito_b_per*255)))

# %%
plt.imshow(tito_3_RGB_per)
plt.show()
tito_3_RGB_per.dtype
# Out:
# dtype('uint8')
